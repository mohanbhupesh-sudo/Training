# %% [markdown]
# What is SciPy?
#
# 1. Free and open-source Python library
# 2. Used for scientific computing and technical computing
# 3. Contains modules for optimization, linear algebra, integration, interpolation, special functions, FFT, signal and image processing

# %% [markdown]
# What are characteristics of SciPy?
#
# 1. Contains toolboxes dedicated to common issues in Scientific Computing
# 2. Different submodules corresponds to different applications
# 3. Operates on Numpy array, Numpy and SciPy work hard in hand
# 4. Adds significant powet to the interactive Python session
# 5. Routines are tested and optimized

# %% [markdown]
# SciPy sub packages
#
# 1. scipy.cluster
#     - Provides kmeans() function
#     - Useful while dividing data into clusters of related attributes
#     - Divide n observations into k clusters
# 2. scipy.stats
#
# 3. scipy.optimize
# 4. scipy.integrate
# 5. scipy.linalg
# 6. scipy.fftpack
# 7. scipy.signal

# %% [markdown]
# What is clustering?
#
# * Dividing data into groups
#
# How do we find clusters?
#
# * Randomly select two cluster centers
# * Assign members to the cluster
# * Calculate the mean distance of each member
# * Shift the cluster center towards mean
# Repeat Step 2 and Step 3 until no member changes the group

# %% [markdown]
# * Now, consider (2.33, 2.33) and (5.5 ,5.5) as K1 and K2
# * Again, find distance of each point from K1 and K2
# * Based on minimim distance put them in clusters
# * Repeat until no member changes the cluster

# %%
import pandas as pd
print("Panda Modules Imported")
# Out:
# Panda Modules Imported

# %%
import pandas as pd

# 1. Create a dictionary with sample data
data = {
    'Name': ['Alice', 'Bob', 'Charlie', 'David'],
    'Age': [25, 30, 22, 35],
    'City': ['New York', 'London', 'Paris', 'Tokyo']
}

# 2. Convert the dictionary into a Pandas DataFrame
df = pd.DataFrame(data)

print("--- Full DataFrame ---")
print(df)

# 3. Access a single column
print("\n--- Age Column Only ---")
print(df['Age'])

# 4. Filter data (Show people older than 25)
print("\n--- Rows where Age > 25 ---")
filtered_df = df[df['Age'] > 25]
print(filtered_df)
# Out:
# --- Full DataFrame ---
#       Name  Age      City
# 0    Alice   25  New York
# 1      Bob   30    London
# 2  Charlie   22     Paris
# 3    David   35     Tokyo
#
# --- Age Column Only ---
# 0    25
# 1    30
# 2    22
# 3    35
# Name: Age, dtype: int64
#
# --- Rows where Age > 25 ---
#     Name  Age    City
# 1    Bob   30  London
# 3  David   35   Tokyo

# %%
import pandas as pd

data = pd.read_excel("randomcars.xlsx")
data
# Out:
#     id   mpg  cyl   disp   hp  drat     wt   qsec  vs  am  gear  carb
# 0    0  21.0    6  160.0  110  3.90  2.620  16.64   0   1     4     4
# 1    1  21.0    6  160.0  110  3.90  2.875  17.02   0   1     4     4
# 2    2  22.9    4  108.0   93  3.85  2.320  18.61   1   1     4     1
# 3    3  21.3    6  268.0  110  3.08  3.215  19.44   1   0     3     1
# 4    4  18.7    8  360.0  175  3.15  3.440  17.02   0   0     3     2
# 5    5  18.1    6  225.0  105  2.76  3.460  20.22   1   0     3     1
# 6    6  14.3    8  360.0  245  3.21  3.570  15.84   0   0     3     4
# 7    7  24.4    4  146.7   62  3.69  3.190  20.00   1   0     4     2
# 8    8  22.8    4  140.8   95  3.92  3.150  22.90   1   0     4     2
# 9    9  19.2    6  167.6  123  3.92  3.440  18.30   1   0     4     4
# 10  10  17.8    6  167.6  123  3.92  3.440  18.90   1   0     4     4
# 11  11  16.4    8  275.8  180  3.07  4.070  17.40   0   0     3     3
# ...

# %%
from scipy.cluster.vq import kmeans, vq
data = pd.read_excel("randomcars.xlsx")
centroid,_ = kmeans(data, 3)
idx, _ = vq(data, centroid)
idx
# Out:
# array([0, 0, 0, 2, 1, 0, 1, 0, 0, 0, 0, 2, 2, 2], dtype=int32)

# %%
print(centroid)
# Out:
# [[5.250000e+00 2.090000e+01 5.250000e+00 1.594625e+02 1.026250e+02
#   3.732500e+00 3.061875e+00 1.907375e+01 7.500000e-01 3.750000e-01
#   3.875000e+00 2.750000e+00]
#  [5.000000e+00 1.650000e+01 8.000000e+00 3.600000e+02 2.100000e+02
#   3.180000e+00 3.505000e+00 1.643000e+01 0.000000e+00 0.000000e+00
#   3.000000e+00 3.000000e+00]
#  [9.750000e+00 1.755000e+01 7.500000e+00 2.738500e+02 1.625000e+02
#   3.072500e+00 3.698750e+00 1.811000e+01 2.500000e-01 0.000000e+00
#   3.000000e+00 2.500000e+00]]

# %%
from scipy.cluster.vq import kmeans, vq, whiten
data=pd.read_excel("randomcars.xlsx")
data = whiten(data)
centroid,_ = kmeans(data, 3)
idx, _ = vq(data, centroid)
idx
# Out:
# array([0, 0, 0, 1, 2, 1, 2, 1, 1, 1, 1, 2, 2, 2], dtype=int32)

# %%
print(centroid)
# Out:
# [[ 0.24806947  7.41154664  3.59240167  1.80211436  2.19846077  9.23416761
#    5.8145462   9.96932575  0.66666667  2.43708718  8.          2.58492131]
#  [ 1.73648628  7.05752824  3.59240167  2.34885397  2.17036542  8.43757204
#    7.40117701 11.42076193  2.          0.          7.33333333  2.01049435]
#  [ 2.28223912  5.61176274  5.38860251  3.9092408   4.04572972  7.404772
#    8.29884176  9.82551723  0.          0.          6.          2.58492131]]

# %% [markdown]
# Why do we use scipy.stats()?
#
# * All of the statistical functions are located in the sub-package scipy.stats
# * Contains a large number of probability distributions
# * Use info(stats) to see all the functions
#
# Example:
# Nutritionists measured the sugar content(in grams) for 13 drinks at Jake's Java Coffee shop. The collected data looks {"sugar": [15, 18, 20, 26, 32, 38, 32, 24, 21, 16, 12, 11, 14]}

# %%
# The drinks had a mean of 21.5g and a standard deviation of 8g, and the distribution was roughly symmetric.
import numpy as np
coffee = np.array([15, 18, 20, 26, 32, 28, 32, 24, 21, 16, 13, 11, 14])
print(coffee.mean(), coffee.std())
import matplotlib.pyplot as pyplot

pyplot.plot(range(13), coffee)
# Out:
# 20.76923076923077 6.840533561666372

# %%
from scipy import stats
print(stats.zscore(coffee))
# Out:
# [-0.843389   -0.40482672 -0.11245187  0.76467269  1.64179726  1.05704755
#   1.64179726  0.47229784  0.03373556 -0.69720157 -1.13576386 -1.42813871
#  -0.98957643]

# %%
print(stats.zscore(coffee))
# Out:
# [-0.843389   -0.40482672 -0.11245187  0.76467269  1.64179726  1.05704755
#   1.64179726  0.47229784  0.03373556 -0.69720157 -1.13576386 -1.42813871
#  -0.98957643]

# %% [markdown]
# Example:
#
# Now, a Grande Mocha Cappuccino at Jake's Java contains 14g of sugar. Calculate the standardized score(z-score) for the Grande Mocha Cappuccino
#
# What does this mean?
#     About 90% of drinks have a higher sugar content than this drink

# %%
obs=np.array([[7,1,3], [87, 18,84], [12, 3, 4], [9, 1, 7]])
chi2, p, dof, expected = stats.chi2_contingency(obs)
p
# Out:
# np.float64(0.48284216946545633)

# %%
import keyword
print(keyword.kwlist)
# Out:
# ['False', 'None', 'True', 'and', 'as', 'assert', 'async', 'await', 'break', 'class', 'continue', 'def', 'del', 'elif', 'else', 'except', 'finally', 'for', 'from', 'global', 'if', 'import', 'in', 'is', 'lambda', 'nonlocal', 'not', 'or', 'pass', 'raise', 'return', 'try', 'while', 'with', 'yield']

# %%
numbers = [0, 1, 2, 3]
print(len(numbers))
# Out:
# 4
